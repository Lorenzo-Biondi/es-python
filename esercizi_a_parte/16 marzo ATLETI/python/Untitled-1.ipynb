# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from math import log
import re

# %%
raw_df = pd.read_excel("/Users/lorenzo/Desktop/Programmazione/python/16 marzo ATLETI/data/Dati infortuni.xlsx")

# %%
#DATAFRAME CORRETTAMENTE ESPORTATO
raw_df.head(5)
# Out:
#   Player_Age Player_Weight Player_Height Previous_Injuries Training_Intensity  \
# 0         24     66.251933    175.732429                 1           0.457929
# 1         37     70.996271     174.58165                 0           0.226522
# 2         32     80.093781    186.329618                 0            0.61397
# 3         28     87.473271     175.50424               one           0.252858
# 4          ඞ             ඞ             ඞ                 ඞ                  ඞ
#
#   Recovery_Time Likelihood_of_Injury  Unnamed: 7
# 0             5                    0         NaN
# 1             6                    1         NaN
# 2             2                    1         NaN
# 3             4                    1         NaN
# 4             ඞ                    ඞ         NaN

# %%
df = raw_df.copy()

# %%
df
# Out:
#     Player_Age Player_Weight Player_Height Previous_Injuries  \
# 0           24     66.251933    175.732429                 1
# 1           37     70.996271     174.58165                 0
# 2           32     80.093781    186.329618                 0
# 3           28     87.473271     175.50424               one
# 4            ඞ             ඞ             ඞ                 ඞ
# ..         ...           ...           ...               ...
# 995         23      99.14791    165.290912                 0
# 996         23     75.799934    178.132281                 1
# 997         20     78.479061    173.823908                 0
# 998         24     66.915802    197.616889                 1
# 999         36     71.847352    177.171535                 0
#
#     Training_Intensity Recovery_Time Likelihood_of_Injury  Unnamed: 7
# 0             0.457929             5                    0         NaN
# 1             0.226522             6                    1         NaN
# 2              0.61397             2                    1         NaN
# 3             0.252858             4                    1         NaN
# 4                    ඞ             ඞ                    ඞ         NaN
# ..                 ...           ...                  ...         ...
# 995           0.077857             3                    1         NaN
# 996           0.955448             1                    0         NaN
# 997           0.246961             1                    1         NaN
# 998           0.859645             2                    0         NaN
# 999            0.16881             1                    0         NaN
#
# [1000 rows x 8 columns]

# %%
df.dtypes
# Out:
# Player_Age               object
# Player_Weight            object
# Player_Height            object
# Previous_Injuries        object
# Training_Intensity       object
# Recovery_Time            object
# Likelihood_of_Injury     object
# Unnamed: 7              float64
# dtype: object

# %%
df["Unnamed: 7"].value_counts(dropna=False)
# Out:
# NaN    999
# 1.0      1
# Name: Unnamed: 7, dtype: int64

# %%
#ENTRATA 832 HA TUTTO SPOSTATO DI UNA COLONNA A DESTRA
df.loc[df["Unnamed: 7"]==1]
# Out:
#     Player_Age Player_Weight Player_Height Previous_Injuries  \
# 832        NaN            36     66.462635        196.774629
#
#     Training_Intensity Recovery_Time Likelihood_of_Injury  Unnamed: 7
# 832                  0      0.131687                    1         1.0

# %%
for idx,i in enumerate(df.columns):
    if idx!=0:
        df.loc[832,df.columns[idx-1]]=df.loc[832,df.columns[idx]]

print(df.loc[832])
# Out:
# Player_Age                      36
# Player_Weight            66.462635
# Player_Height           196.774629
# Previous_Injuries                0
# Training_Intensity        0.131687
# Recovery_Time                    1
# Likelihood_of_Injury           1.0
# Unnamed: 7                     1.0
# Name: 832, dtype: object

# %%
df=df.drop(['Unnamed: 7'],axis=1)
df
# Out:
#     Player_Age Player_Weight Player_Height Previous_Injuries  \
# 0           24     66.251933    175.732429                 1
# 1           37     70.996271     174.58165                 0
# 2           32     80.093781    186.329618                 0
# 3           28     87.473271     175.50424               one
# 4            ඞ             ඞ             ඞ                 ඞ
# ..         ...           ...           ...               ...
# 995         23      99.14791    165.290912                 0
# 996         23     75.799934    178.132281                 1
# 997         20     78.479061    173.823908                 0
# 998         24     66.915802    197.616889                 1
# 999         36     71.847352    177.171535                 0
#
#     Training_Intensity Recovery_Time Likelihood_of_Injury
# 0             0.457929             5                    0
# 1             0.226522             6                    1
# 2              0.61397             2                    1
# 3             0.252858             4                    1
# 4                    ඞ             ඞ                    ඞ
# ..                 ...           ...                  ...
# 995           0.077857             3                    1
# 996           0.955448             1                    0
# 997           0.246961             1                    1
# 998           0.859645             2                    0
# 999            0.16881             1                    0
#
# [1000 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Player_Age              10
# Player_Weight            2
# Player_Height            2
# Previous_Injuries        6
# Training_Intensity       2
# Recovery_Time            2
# Likelihood_of_Injury     2
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
#     Player_Age Player_Weight Player_Height Previous_Injuries  \
# 223          ඞ             ඞ             ඞ                 ඞ
#
#     Training_Intensity Recovery_Time Likelihood_of_Injury
# 223                  ඞ             ඞ                    ඞ

# %%
df.loc[df["Player_Age"] == "ඞ"]
# Out:
#     Player_Age Player_Weight Player_Height Previous_Injuries  \
# 4            ඞ             ඞ             ඞ                 ඞ
# 113          ඞ             ඞ             ඞ                 ඞ
# 223          ඞ             ඞ             ඞ                 ඞ
#
#     Training_Intensity Recovery_Time Likelihood_of_Injury
# 4                    ඞ             ඞ                    ඞ
# 113                  ඞ                                  ඞ
# 223                  ඞ             ඞ                    ඞ

# %%
df = df.drop(df[df['Player_Age'] == "ඞ"].index)

# %%
#TUTTE LE ENTRIES CON ENTRATE NON NUMERICHE
df[~df.applymap(np.isreal).all(1)]
# Out:
#     Player_Age Player_Weight Player_Height Previous_Injuries  \
# 3           28     87.473271     175.50424               one
# 6           24      70.12605    177.044588                 #
# 7          36'     79.038206    181.523155                 1
# 81         32'     63.928955    177.330853                 1
# 90          18      73.50122    176.963385               one
# 122         20     82.563516    160.638847               one
# 125         31     53.301223    166.832512              zero
# 135        37'      70.81857    157.230088                 1
# 136         21     62.115526    181.408284              zero
# 139         30     80.518637    179.365539              zero
# 191         22      81.18662    180.301616                 #
# 192         18     87.862686    177.434121                 #
# 196         38     59.734481     194.79079              zero
# 197         29     74.420951    186.111437               one
# 198         23     83.184847    202.908839                 #
# 199        21'     76.338477    181.070424                 0
# 817         31     83.795926    196.953885                 1
# 821         36     69.975375    163.764448                 0
# 833        32'     78.592094    175.075539                 0
# 967         22     69.265622    188.382369              zero
# 970         21     65.236247     183.61442               one
# 982        32ì     57.371675    177.242978                 1
# 988        31'     73.904507    178.060506                 0
#
#     Training_Intensity Recovery_Time Likelihood_of_Injury
# 3             0.252858             4                    1
# 6             0.823552             2                    0
# 7             0.820696             3                    1
# 81            0.677438             6                    1
# 90             0.37904             2                    0
# 122           0.222676             1                    1
# 125           0.417193             2                    1
# 135           0.661719             6                    0
# 136           0.602449             2                    0
# 139           0.023708             5                    1
# 191           0.760161             1                    1
# 192             0.1539             2                    1
# 196           0.408456             5                    0
# 197           0.679697             6                    1
# 198            0.05668             6                    0
# 199           0.034673             6                    0
# 817           0.645725             4                 zero
# 821           0.802396             6                 zero
# 833           0.705041             3                    0
# 967           0.241165             2                    0
# 970           0.187124             5                    0
# 982            0.29765             3                    0
# 988           0.634907             6                    0

# %%
df["Previous_Injuries"] = df["Previous_Injuries"].replace("one",1)
df["Previous_Injuries"] = df["Previous_Injuries"].replace("zero",0)
df["Previous_Injuries"] = df["Previous_Injuries"].replace("#",None)
df[~df.applymap(np.isreal).all(1)]
# Out:
#     Player_Age Player_Weight Player_Height Previous_Injuries  \
# 7          36'     79.038206    181.523155                 1
# 81         32'     63.928955    177.330853                 1
# 135        37'      70.81857    157.230088                 1
# 199        21'     76.338477    181.070424                 0
# 817         31     83.795926    196.953885                 1
# 821         36     69.975375    163.764448                 0
# 833        32'     78.592094    175.075539                 0
# 982        32ì     57.371675    177.242978                 1
# 988        31'     73.904507    178.060506                 0
#
#     Training_Intensity Recovery_Time Likelihood_of_Injury
# 7             0.820696             3                    1
# 81            0.677438             6                    1
# 135           0.661719             6                    0
# 199           0.034673             6                    0
# 817           0.645725             4                 zero
# 821           0.802396             6                 zero
# 833           0.705041             3                    0
# 982            0.29765             3                    0
# 988           0.634907             6                    0

# %%
df["Likelihood_of_Injury"] = df["Likelihood_of_Injury"].replace("zero",0)
df[~df.applymap(np.isreal).all(1)]
# Out:
#     Player_Age Player_Weight Player_Height Previous_Injuries  \
# 7          36'     79.038206    181.523155                 1
# 81         32'     63.928955    177.330853                 1
# 135        37'      70.81857    157.230088                 1
# 199        21'     76.338477    181.070424                 0
# 833        32'     78.592094    175.075539                 0
# 982        32ì     57.371675    177.242978                 1
# 988        31'     73.904507    178.060506                 0
#
#     Training_Intensity Recovery_Time  Likelihood_of_Injury
# 7             0.820696             3                   1.0
# 81            0.677438             6                   1.0
# 135           0.661719             6                   0.0
# 199           0.034673             6                   0.0
# 833           0.705041             3                   0.0
# 982            0.29765             3                   0.0
# 988           0.634907             6                   0.0

# %%
df.Previous_Injuries.value_counts()
# Out:
# 1    512
# 0    475
# Name: Previous_Injuries, dtype: int64

# %%
df['Previous_Injuries'] = df['Previous_Injuries'].astype('bool')

# %%
df.Likelihood_of_Injury.value_counts()
# Out:
#  0.0    498
#  1.0    496
# -1.0      1
# Name: Likelihood_of_Injury, dtype: int64

# %%
df["Likelihood_of_Injury"] = df["Likelihood_of_Injury"].replace(-1,1)

# %%
df.Likelihood_of_Injury.value_counts()
# Out:
# 0.0    498
# 1.0    497
# Name: Likelihood_of_Injury, dtype: int64

# %%
df["Likelihood_of_Injury"] = df["Likelihood_of_Injury"].astype("bool")

# %%
df["Player_Age"].value_counts(dropna=False)
# Out:
# 18     60
# 22     56
# 20     56
# 34     53
# 36     50
# 25     47
# 38     46
# 29     46
# 32     45
# 39     45
# 19     45
# 30     44
# 33     43
# 23     43
# 24     42
# 21     42
# 26     40
# 37     37
# 31     36
# 27     35
# 35     35
# 28     34
# NaN    10
# 32'     2
# 36'     1
# 37'     1
# 21'     1
# 32ì     1
# 31'     1
# Name: Player_Age, dtype: int64

# %%
caratteri_non_desiderati = "[^0-9]"
df["Player_Age"]= df.Player_Age.replace(caratteri_non_desiderati,"",regex=True)

# %%
df["Player_Age"].value_counts()
# Out:
# 18    60
# 22    56
# 20    56
# 34    53
# 36    50
# 25    47
# 38    46
# 29    46
# 32    45
# 39    45
# 19    45
# 30    44
# 23    43
# 33    43
# 24    42
# 21    42
# 26    40
# 37    37
# 31    36
# 27    35
# 35    35
# 28    34
# 32     3
# 36     1
# 37     1
# 21     1
# 31     1
# Name: Player_Age, dtype: int64

# %%
df["Player_Age"] = df["Player_Age"].astype(float)

# %%
df["Player_Age"].value_counts()
# Out:
# 18.0    60
# 22.0    56
# 20.0    56
# 34.0    53
# 36.0    51
# 32.0    48
# 25.0    47
# 29.0    46
# 38.0    46
# 39.0    45
# 19.0    45
# 30.0    44
# 23.0    43
# 21.0    43
# 33.0    43
# 24.0    42
# 26.0    40
# 37.0    38
# 31.0    37
# 27.0    35
# 35.0    35
# 28.0    34
# Name: Player_Age, dtype: int64

# %%
#TUTTI I DATI SONO NUMERICI
df[~df.applymap(np.isreal).all(1)]
# Out:
# Empty DataFrame
# Columns: [Player_Age, Player_Weight, Player_Height, Previous_Injuries, Training_Intensity, Recovery_Time, Likelihood_of_Injury]
# Index: []

# %%
df.dtypes
# Out:
# Player_Age              float64
# Player_Weight            object
# Player_Height            object
# Previous_Injuries          bool
# Training_Intensity       object
# Recovery_Time            object
# Likelihood_of_Injury       bool
# dtype: object

# %%
df["Player_Height"] = df["Player_Height"].astype(float)

# %%
df["Player_Weight"] = df["Player_Weight"].astype(float)

# %%
df["Training_Intensity"] = df["Training_Intensity"].astype(float)

# %%
df["Recovery_Time"] = df["Recovery_Time"].astype(float)

# %%
df.dtypes
# Out:
# Player_Age              float64
# Player_Weight           float64
# Player_Height           float64
# Previous_Injuries          bool
# Training_Intensity      float64
# Recovery_Time           float64
# Likelihood_of_Injury       bool
# dtype: object

# %%
df.isna().sum()
# Out:
# Player_Age              10
# Player_Weight            2
# Player_Height            2
# Previous_Injuries        0
# Training_Intensity       2
# Recovery_Time            2
# Likelihood_of_Injury     0
# dtype: int64

# %%
df.loc[df["Player_Age"].isnull()]
# Out:
#      Player_Age  Player_Weight  Player_Height  Previous_Injuries  \
# 154         NaN      60.656350     170.892962               True
# 159         NaN      66.162222     187.792340              False
# 173         NaN      77.425204     191.635088               True
# 183         NaN      84.294825     182.300095               True
# 207         NaN      80.010333     167.599397               True
# 219         NaN      80.855035     178.056685               True
# 826         NaN      69.166420     171.356089               True
# 848         NaN      78.041262     184.078768               True
# 861         NaN      74.141068     182.848686              False
# 936         NaN            NaN            NaN               True
#
#      Training_Intensity  Recovery_Time  Likelihood_of_Injury
# 154            0.787372            1.0                 False
# 159            0.973800            4.0                 False
# 173            0.817305            2.0                  True
# 183            0.492535            3.0                  True
# 207            0.297287            2.0                 False
# 219            0.671271            6.0                  True
# 826            0.662314            4.0                  True
# 848            0.720384            6.0                  True
# 861            0.725372            3.0                 False
# 936                 NaN            NaN                  True

# %%
df = df.drop([936])

# %%
df.loc[df["Player_Age"].isnull()]
# Out:
#      Player_Age  Player_Weight  Player_Height  Previous_Injuries  \
# 154         NaN      60.656350     170.892962               True
# 159         NaN      66.162222     187.792340              False
# 173         NaN      77.425204     191.635088               True
# 183         NaN      84.294825     182.300095               True
# 207         NaN      80.010333     167.599397               True
# 219         NaN      80.855035     178.056685               True
# 826         NaN      69.166420     171.356089               True
# 848         NaN      78.041262     184.078768               True
# 861         NaN      74.141068     182.848686              False
#
#      Training_Intensity  Recovery_Time  Likelihood_of_Injury
# 154            0.787372            1.0                 False
# 159            0.973800            4.0                 False
# 173            0.817305            2.0                  True
# 183            0.492535            3.0                  True
# 207            0.297287            2.0                 False
# 219            0.671271            6.0                  True
# 826            0.662314            4.0                  True
# 848            0.720384            6.0                  True
# 861            0.725372            3.0                 False

# %%
df["Player_Age"].hist()
# Out:
# <Axes: >

# %%
df['Player_Age'] = df['Player_Age'].fillna(df['Player_Age'].median())
df["Player_Age"].hist()
# Out:
# <Axes: >

# %%
#NONE TOLTI
df.loc[df["Player_Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Player_Age, Player_Weight, Player_Height, Previous_Injuries, Training_Intensity, Recovery_Time, Likelihood_of_Injury]
# Index: []

# %%
df[df.isna().any(axis=1)]
# Out:
#      Player_Age  Player_Weight  Player_Height  Previous_Injuries  \
# 128        32.0            NaN            NaN               True
#
#      Training_Intensity  Recovery_Time  Likelihood_of_Injury
# 128                 NaN            NaN                  True

# %%
df = df.drop([128])

# %%
df.isnull().sum()
# Out:
# Player_Age              0
# Player_Weight           0
# Player_Height           0
# Previous_Injuries       0
# Training_Intensity      0
# Recovery_Time           0
# Likelihood_of_Injury    0
# dtype: int64

# %%
df.shape
# Out:
# (995, 7)

# %%
df["Player_Age"].hist()
# Out:
# <Axes: >

# %%
df['Player_Age'].value_counts().plot(kind='bar', color='green')
# Out:
# <Axes: >

# %%
df["Player_Height"].hist()
# Out:
# <Axes: >

# %%
# Apply log transformation to the data
log_data = np.log(df["Player_Height"])

plt.hist(log_data, bins=100, label='')
#plt.hist(df["sellingprice"], bins=100, label='')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df["Player_Weight"].hist()
# Out:
# <Axes: >

# %%
df["Training_Intensity"].hist()
# Out:
# <Axes: >

# %%
df["Training_Intensity"].max()
# Out:
# 0.9977493890102

# %%
df["Training_Intensity"].min()
# Out:
# 3.0718845382416e-05

# %%
df["Recovery_Time"].hist()
# Out:
# <Axes: >

# %%
df["Likelihood_of_Injury"].value_counts().plot(autopct='%1.1f%%',kind="pie")
# Out:
# <Axes: ylabel='Likelihood_of_Injury'>

# %%
df["Previous_Injuries"].value_counts().plot(autopct='%1.1f%%',kind="pie")
# Out:
# <Axes: ylabel='Previous_Injuries'>

# %% [markdown]
# # ANALISI BIVARIATA

# %%
df.corr()
# Out:
#                       Player_Age  Player_Weight  Player_Height  \
# Player_Age              1.000000      -0.038435       0.049504
# Player_Weight          -0.038435       1.000000       0.028684
# Player_Height           0.049504       0.028684       1.000000
# Previous_Injuries      -0.053506       0.037428       0.010534
# Training_Intensity      0.037679       0.045071       0.047021
# Recovery_Time          -0.033157      -0.062003       0.033645
# Likelihood_of_Injury    0.002038       0.003291       0.031109
#
#                       Previous_Injuries  Training_Intensity  Recovery_Time  \
# Player_Age                    -0.053506            0.037679      -0.033157
# Player_Weight                  0.037428            0.045071      -0.062003
# Player_Height                  0.010534            0.047021       0.033645
# Previous_Injuries              1.000000           -0.022999      -0.011407
# Training_Intensity            -0.022999            1.000000      -0.032232
# Recovery_Time                 -0.011407           -0.032232       1.000000
# Likelihood_of_Injury           0.033226            0.093156      -0.012748
#
#                       Likelihood_of_Injury
# Player_Age                        0.002038
# Player_Weight                     0.003291
# Player_Height                     0.031109
# Previous_Injuries                 0.033226
# Training_Intensity                0.093156
# Recovery_Time                    -0.012748
# Likelihood_of_Injury              1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(x=df["Player_Height"],y=df["Player_Weight"])

# %%
#COLONNA DEL BMI
df["Player_BMI"] = df["Player_Weight"]/((df["Player_Height"]/100)**2)
df
# Out:
#      Player_Age  Player_Weight  Player_Height  Previous_Injuries  \
# 0          24.0      66.251933     175.732429               True
# 1          37.0      70.996271     174.581650              False
# 2          32.0      80.093781     186.329618              False
# 3          28.0      87.473271     175.504240               True
# 5          38.0      75.820549     206.631824               True
# ..          ...            ...            ...                ...
# 995        23.0      99.147910     165.290912              False
# 996        23.0      75.799934     178.132281               True
# 997        20.0      78.479061     173.823908              False
# 998        24.0      66.915802     197.616889               True
# 999        36.0      71.847352     177.171535              False
#
#      Training_Intensity  Recovery_Time  Likelihood_of_Injury  Player_BMI
# 0              0.457929            5.0                 False   21.453331
# 1              0.226522            6.0                  True   23.293693
# 2              0.613970            2.0                  True   23.069332
# 3              0.252858            4.0                  True   28.398810
# 5              0.359209            4.0                 False   17.757937
# ..                  ...            ...                   ...         ...
# 995            0.077857            3.0                  True   36.289886
# 996            0.955448            1.0                 False   23.888208
# 997            0.246961            1.0                  True   25.973757
# 998            0.859645            2.0                 False   17.134860
# 999            0.168810            1.0                 False   22.888792
#
# [995 rows x 8 columns]

# %%
df["Player_BMI"].hist()
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(x=df["Player_BMI"],y=df["Player_Height"])

# %%
plt.scatter(x=df["Player_BMI"],y=df["Player_Weight"])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
gaps = [-float('inf'), 18.5, 24.9, 29.9, 34.9, float('inf')]
categories = ['sottopeso', 'Normale', 'Sovrappeso', 'Obeso', 'Gravemente obeso']


df['BMI_Classification'] = pd.cut(df['Player_BMI'], bins=gaps, labels=categories, right=False)

# %%
df["BMI_Classification"].value_counts()
# Out:
# Normale             570
# Sovrappeso          259
# sottopeso           105
# Obeso                53
# Gravemente obeso      8
# Name: BMI_Classification, dtype: int64

# %%
sns.violinplot(data=df, x="BMI_Classification", y="Player_Age", hue="Previous_Injuries", split=True, gap=.1, inner="quart")
# Out:
# <Axes: xlabel='BMI_Classification', ylabel='Player_Age'>

# %%
sns.violinplot(data=df, x="BMI_Classification", y="Player_Age", hue="Likelihood_of_Injury", split=True, gap=.1, inner="quart")
# Out:
# <Axes: xlabel='BMI_Classification', ylabel='Player_Age'>

# %%
'''dfp = df.pivot_table(index='BMI_Classification', columns='Previous_Injuries', values='Previous_Injuries', aggfunc='size')

# plot
dfp.plot(kind='bar', rot=0)
plt.show()'''
# Out:
# "dfp = df.pivot_table(index='BMI_Classification', columns='Previous_Injuries', values='Previous_Injuries', aggfunc='size')\n\n# plot\ndfp.plot(kind='bar', rot=0)\nplt.show()"

# %%
gaps_2 = [-float('inf'), 0.2, 0.4, 0.6, 0.8, float('inf')]
categories_2 = ['non si allena', 'poco', 'abbastanza', 'molto', 'moltissimo']


df['Training_Classification'] = pd.cut(df['Training_Intensity'], bins=gaps_2, labels=categories_2, right=False)

# %%
sns.violinplot(data=df, x="Training_Classification", y="Player_Age", hue="Previous_Injuries", split=True, gap=.1, inner="quart")
# Out:
# <Axes: xlabel='Training_Classification', ylabel='Player_Age'>

# %%
sns.violinplot(data=df, x="Training_Classification", y="Player_Age", hue="Likelihood_of_Injury", split=True, gap=.1, inner="quart")
# Out:
# <Axes: xlabel='Training_Classification', ylabel='Player_Age'>

# %%
gaps_3 = [-float('inf'), 22, 27, 31, 35,float('inf')]
categories_3 = ['18-22', '23-27', '28-31', '31-35', '35+']

# Create "BMI_Classification" column 
df['Age_Classification'] = pd.cut(df['Player_Age'], bins=gaps_3, labels=categories_3, right=False)

# %%
sns.violinplot(data=df, x="Age_Classification", y="Training_Classification", hue="Previous_Injuries", split=True, gap=.1, inner="quart")
# Out:
# <Axes: xlabel='Age_Classification', ylabel='Training_Classification'>

# %%
sns.violinplot(data=df, x="Age_Classification", y="Training_Classification", hue="Likelihood_of_Injury", split=True, gap=.1, inner="quart")
# Out:
# <Axes: xlabel='Age_Classification', ylabel='Training_Classification'>

# %%
sns.displot(df, x="Training_Intensity", kind="kde")

# %%
sns.kdeplot(data=df, x='Training_Intensity', hue='Previous_Injuries')
# Out:
# <Axes: xlabel='Training_Intensity', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='Training_Intensity', hue='Likelihood_of_Injury')
# Out:
# <Axes: xlabel='Training_Intensity', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='Training_Intensity', hue='Age_Classification')
# Out:
# <Axes: xlabel='Training_Intensity', ylabel='Density'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# /var/folders/r_/fs8t89rd1mzfn7vs0ld413940000gn/T/ipykernel_3135/621126171.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
sns.pairplot(df)
